# %% [markdown]
# # Data Science Internship – February 2026
# ## Logic Building Task – 2
#
# **Author:** Neeraj
#
# ### Description
# This notebook contains solutions for all 10 assigned logic-building tasks, implemented using clean and well-structured Python code.
#
# ### Tasks Covered
# 1. Unique Words in a Sentence
# 2. Highest Salary from Employee Data
# 3. Find Maximum and Minimum Values
# 4. Count Products Above a Price Threshold
# 5. Calculate Attendance Percentage
# 6. Remove Duplicate Phone Numbers
# 7. Count Character Frequency
# 8. Convert List to Tuple
# 9. Check if a Key Exists in a Dictionary
# 10. Calculate Average Marks

# %% [markdown]
# ## 1. Unique Words in a Sentence
#
# **Problem Statement:**
# Given a sentence, identify all unique words and display:
# 1. The count of unique words
# 2. The unique words themselves

# %%
sentence=input("Enter sentence: ").split()
UniqueWords=[]
seen=set()

for i in sentence:
    if i not in seen:
        UniqueWords.append(i)
        seen.add(i)

print(f"Unique words count: {len(UniqueWords)}")
print("Unique words:", "{" + ",".join(f"'{i}'" for i in UniqueWords) + "}")
# Out:
# Enter sentence:  python is easy and python is powerful
# Unique words count: 5
# Unique words: {'python','is','easy','and','powerful'}

# %% [markdown]
# ## 2 Highest Salary from Employee Data
#
# **Problem Statement:**
# Store employee names and their salaries, and determine which employee has the highest salary.

# %%
employees={}
n=int(input("Enter number of employees: "))

for i in range(n):
    Name,Salary=input(f"Enter employee data {i+1} (Name:Salary): ").split(":")
    employees[Name.strip()]=int(Salary.strip())

HighestEmployee=None
HighestSalary=0

for Name,Salary in employees.items():
    if Salary>HighestSalary:
        HighestSalary=Salary
        HighestEmployee=Name

print(f"Highest Salary: {HighestEmployee} - {HighestSalary}")
# Out:
# Enter number of employees:  3
# Enter employee data 1 (Name:Salary):  Ravi:75000
# Enter employee data 2 (Name:Salary):  Anita:68000
# Enter employee data 3 (Name:Salary):  Kiran:72000
# Highest Salary: Ravi - 75000

# %% [markdown]
# ## 3. Find Maximum and Minimum Values
#
# **Problem Statement:**
# Find the maximum and minimum values from a list of numbers.

# %%
n=list(map(int, input("Enter numbers separated by coma: ").split(",")))

maximum=n[0]
minimum=n[0]

for i in n:
    if i>maximum:
        maximum=i
    if i<minimum:
        minimum=i
        
print(f"List: {n}")
print(f"Max: {maximum}")
print(f"Min: {minimum}")
# Out:
# Enter numbers separated by coma:  45, 22, 89, 10, 66
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# ## 4. Count Products Above a Price Threshold
#
# **Problem Statement:**
# Count how many products have a price greater than 1000.

# %%
prices=list(map(int,input("Enter prices separated by coma: ").split(",")))
count=0

for i in prices:
    if i > 1000:
        count += 1

print(f"Products above 1000: {count}")
# Out:
# Enter prices separated by coma:  450, 1200, 899, 1500, 300
# Products above 1000: 2

# %% [markdown]
# ## 5. Calculate Attendance Percentage
#
# **Problem Statement:**
# Calculate the attendance percentage from a list containing "P" (Present) and "A" (Absent).

# %%
attendance=input("Enter attendance values separated by comma (P/A): ").upper().split(",")
attendance=[x.strip() for x in attendance]
PresentCount=attendance.count("P")
print(f"Attendance Percentage: {(PresentCount / len(attendance)) * 100}")
# Out:
# Enter attendance values separated by comma (P/A):  P, P, A, P,P
# Attendance Percentage: 80.0

# %% [markdown]
# ## 6. Remove Duplicate Phone Numbers
#
# **Problem Statement:**
# You are given a list of phone numbers that may contain duplicates. Write a Python program to remove duplicate phone numbers and display only the unique phone numbers.

# %%
PhoneNumbers=input("Enter phone numbers separated by comma: ").split(",")
UniqueNumbers={i.strip() for i in PhoneNumbers}
print(f"Unique phone numbers: {UniqueNumbers}")
# Out:
# Enter phone numbers separated by comma:  9876543210, 9123456789, 9876543210
# Unique phone numbers: {'9876543210', '9123456789'}

# %% [markdown]
# ## 7. Count Character Frequency
#
# **Problem Statement:**
# Count how many times each character appears in a given string.

# %%
text=input("Enter a string: ").lower()
CharFrequency={}

for i in text:
    if i in CharFrequency:
        CharFrequency[i]+=1
    else:
        CharFrequency[i]=1

print(CharFrequency)
# Out:
# Enter a string:  python
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# ## 8. Convert List to Tuple
#
# **Problem Statement:**
# Convert a list into a tuple and display it.

# %%
ListInput=list(map(int,input("Enter numbers separated by coma: ").strip().split(",")))
print(f"Tuple: {tuple(ListInput)}")
# Out:
# Enter numbers separated by coma:  10,20,30
# Tuple: (10, 20, 30)

# %% [markdown]
# ## 9. Check if a Key Exists in a Dictionary
#
# **Problem Statement:**
# Check whether a specific key exists in a dictionary.

# %%
employees={}
n=int(input("Enter number of employees: "))

for i in range(n):
    Name,Salary=input(f"Enter employee data {i+1} (Name:Salary): ").split(":")
    employees[Name.strip()] = int(Salary.strip())

KeyToCheck=input("Enter employee name to check: ")

if KeyToCheck in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Enter number of employees:  3
# Enter employee data 1 (Name:Salary):  Ravi:75000
# Enter employee data 2 (Name:Salary):  Anita:68000
# Enter employee data 3 (Name:Salary):  Kiran: 72000
# Enter employee name to check:  Ravi
# Employee exists

# %% [markdown]
# ## 10. Calculate Average Marks
#
# **Problem Statement:**
# Calculate the average marks of a student from a list of marks.

# %%
marks=list(map(int,input("Enter marks separated by coma: ").strip().split(',')))
print(f"Average Marks: {sum(marks)/len(marks):.2f}")
# Out:
# Enter marks separated by coma:  100,50,25,78,65
# Average Marks: 63.60
